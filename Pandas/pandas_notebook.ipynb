# %% [markdown]
# # Project

# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ## Load Lib

# %% [markdown]
# ### Load DataFrames

# %%
data = {
'Name': ['Alice', 'Bob', 'Charlie', 'Diana'],
'Age': [25, 30, 35, 28],
'Score': [88.5, 92.0, 79.3, 95.1]
}

df = pd.DataFrame(data)
print(df)
# Out:
#       Name  Age  Score
# 0    Alice   25   88.5
# 1      Bob   30   92.0
# 2  Charlie   35   79.3
# 3    Diana   28   95.1

# %% [markdown]
# ### Creating DataFrames

# %% [markdown]
# # DataSet Load

# %%
df = pd.read_csv('data/Titanic.csv')
df
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 0                                Kelly, Mr. James    male  34.5      0      0
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# ...

# %% [markdown]
# ## Row Selection loc and Iloc

# %%
# .loc[row_label, col_label]

#df.loc[0] -- > row with index label 0
#df.loc[0, 'Name'] -->single value
#df.loc[0:2, 'Name':'Age'] -->slice rows AND cols by label
#df.loc[df['Age'] > 28] --> boolean selection

#####################

# .iloc[row_position, col_position]

#df.iloc[0] --> First row
#df.iloc[0, 1] --> First row, second column 
#df.iloc[0:3, 0:2] --> first 3 rows, first 2 cols
df.iloc[-1] # --> last row
#df.iloc[:, 2] # all rows, col at position 2
# Out:
# PassengerId                        1309
# Survived                              0
# Pclass                                3
# Name           Peter, Master. Michael J
# Sex                                male
# Age                                 NaN
# SibSp                                 1
# Parch                                 1
# Ticket                             2668
# Fare                            22.3583
# Cabin                               NaN
# Embarked                              C
# Name: 417, dtype: object

# %% [markdown]
# # View and Inspection

# %% [markdown]
# ### Info --> What type of data?

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 418 entries, 0 to 417
# Data columns (total 12 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   PassengerId  418 non-null    int64
#  1   Survived     418 non-null    int64
#  2   Pclass       418 non-null    int64
#  3   Name         418 non-null    str
#  4   Sex          418 non-null    str
#  5   Age          332 non-null    float64
#  6   SibSp        418 non-null    int64
#  7   Parch        418 non-null    int64
#  8   Ticket       418 non-null    str
#  9   Fare         417 non-null    float64
#  10  Cabin        91 non-null     str
#  11  Embarked     418 non-null    str
# dtypes: float64(2), int64(5), str(5)
# memory usage: 39.3 KB

# %% [markdown]
# ### Selecting Data

# %%
#name = df['Name']
#name
#type (name) --> Series
#type (names) --> DataFrame
names = df[['Name','Age']]
names
# Out:
#                                              Name   Age
# 0                                Kelly, Mr. James  34.5
# 1                Wilkes, Mrs. James (Ellen Needs)  47.0
# 2                       Myles, Mr. Thomas Francis  62.0
# 3                                Wirz, Mr. Albert  27.0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  22.0
# ..                                            ...   ...
# 413                            Spector, Mr. Woolf   NaN
# 414                  Oliva y Ocana, Dona. Fermina  39.0
# 415                  Saether, Mr. Simon Sivertsen  38.5
# 416                           Ware, Mr. Frederick   NaN
# 417                      Peter, Master. Michael J   NaN
#
# [418 rows x 2 columns]

# %% [markdown]
# ### Tail Gives last 5 rows of the dataset

# %%
df.tail()
# Out:
#      PassengerId  Survived  Pclass                          Name     Sex  \
# 413         1305         0       3            Spector, Mr. Woolf    male
# 414         1306         1       1  Oliva y Ocana, Dona. Fermina  female
# 415         1307         0       3  Saether, Mr. Simon Sivertsen    male
# 416         1308         0       3           Ware, Mr. Frederick    male
# 417         1309         0       3      Peter, Master. Michael J    male
#
#       Age  SibSp  Parch              Ticket      Fare Cabin Embarked
# 413   NaN      0      0           A.5. 3236    8.0500   NaN        S
# 414  39.0      0      0            PC 17758  108.9000  C105        C
# 415  38.5      0      0  SOTON/O.Q. 3101262    7.2500   NaN        S
# 416   NaN      0      0              359309    8.0500   NaN        S
# 417   NaN      1      1                2668   22.3583   NaN        C

# %% [markdown]
# ### Describe Info in Quartile, Interquartile, Max, Min

# %%
df.describe()
# Out:
#        PassengerId    Survived      Pclass         Age       SibSp  \
# count   418.000000  418.000000  418.000000  332.000000  418.000000
# mean   1100.500000    0.363636    2.265550   30.272590    0.447368
# std     120.810458    0.481622    0.841838   14.181209    0.896760
# min     892.000000    0.000000    1.000000    0.170000    0.000000
# 25%     996.250000    0.000000    1.000000   21.000000    0.000000
# 50%    1100.500000    0.000000    3.000000   27.000000    0.000000
# 75%    1204.750000    1.000000    3.000000   39.000000    1.000000
# max    1309.000000    1.000000    3.000000   76.000000    8.000000
#
#             Parch        Fare
# count  418.000000  417.000000
# mean     0.392344   35.627188
# std      0.981429   55.907576
# min      0.000000    0.000000
# 25%      0.000000    7.895800
# 50%      0.000000   14.454200
# 75%      0.000000   31.500000
# max      9.000000  512.329200

# %% [markdown]
# ### Head Gives first 5 rows of the dataset

# %%
df.head()
# Out:
#    PassengerId  Survived  Pclass  \
# 0          892         0       3
# 1          893         1       3
# 2          894         0       2
# 3          895         0       3
# 4          896         1       3
#
#                                            Name     Sex   Age  SibSp  Parch  \
# 0                              Kelly, Mr. James    male  34.5      0      0
# 1              Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                     Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                              Wirz, Mr. Albert    male  27.0      0      0
# 4  Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
#
#     Ticket     Fare Cabin Embarked
# 0   330911   7.8292   NaN        Q
# 1   363272   7.0000   NaN        S
# 2   240276   9.6875   NaN        Q
# 3   315154   8.6625   NaN        S
# 4  3101298  12.2875   NaN        S

# %% [markdown]
# # Boolean Conditionting

# %%
df[(df['Age'] > 25) & (df['Fare'] >= 7.0)]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 6            898         1       3
# ..           ...       ...     ...
# 407         1299         0       1
# 411         1303         1       1
# 412         1304         1       3
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 3                                   Wirz, Mr. Albert    male  27.0      0
# 6                               Connolly, Miss. Kate  female  30.0      0
# ..                                               ...     ...   ...    ...
# ...

# %%
df[~df['Name'].str.contains('Kelly')] # Not Containing 'Kelly'
# Out:
#      PassengerId  Survived  Pclass  \
# 1            893         1       3
# 2            894         0       2
# 3            895         0       3
# 4            896         1       3
# 5            897         0       3
# ..           ...       ...     ...
# 413         1305         0       3
# 414         1306         1       1
# 415         1307         0       3
# 416         1308         0       3
# 417         1309         0       3
#
#                                              Name     Sex   Age  SibSp  Parch  \
# 1                Wilkes, Mrs. James (Ellen Needs)  female  47.0      1      0
# 2                       Myles, Mr. Thomas Francis    male  62.0      0      0
# 3                                Wirz, Mr. Albert    male  27.0      0      0
# 4    Hirvonen, Mrs. Alexander (Helga E Lindqvist)  female  22.0      1      1
# 5                      Svensson, Mr. Johan Cervin    male  14.0      0      0
# ...

# %%
df[df['Sex'] == 'male'].count()
# Out:
# PassengerId    266
# Survived       266
# Pclass         266
# Name           266
# Sex            266
# Age            205
# SibSp          266
# Parch          266
# Ticket         266
# Fare           265
# Cabin           47
# Embarked       266
# dtype: int64

# %%
df[df['Age'] > 28]
# Out:
#      PassengerId  Survived  Pclass  \
# 0            892         0       3
# 1            893         1       3
# 2            894         0       2
# 6            898         1       3
# 11           903         0       1
# ..           ...       ...     ...
# 404         1296         0       1
# 407         1299         0       1
# 411         1303         1       1
# 414         1306         1       1
# 415         1307         0       3
#
#                                                 Name     Sex   Age  SibSp  \
# 0                                   Kelly, Mr. James    male  34.5      0
# 1                   Wilkes, Mrs. James (Ellen Needs)  female  47.0      1
# 2                          Myles, Mr. Thomas Francis    male  62.0      0
# 6                               Connolly, Miss. Kate  female  30.0      0
# 11                        Jones, Mr. Charles Cresson    male  46.0      0
# ..                                               ...     ...   ...    ...
# ...
